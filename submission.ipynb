# %%
import os 
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
plays = pd.read_csv('plays.csv')
players = pd.read_csv('players.csv')
playerplay = pd.read_csv('player_play.csv')
df = pd.read_csv('tracking_week_1.csv')

# %%
cols = ['gameId','playId', 'possessionTeam','defensiveTeam','quarter', 'down', 'yardsToGo', 'offenseFormation', 'receiverAlignment','passResult','playAction', 'timeToThrow','pff_passCoverage','pff_manZone']

# %%
filteredplays = plays.loc[plays['passResult'].notna(), cols]

# %%
filteredplays[(filteredplays.gameId == 2022090800) & (filteredplays.playId == 56)]
# Out:
#            gameId  playId possessionTeam defensiveTeam  quarter  down  \
# 13368  2022090800      56            BUF            LA        1     1
#
#        yardsToGo offenseFormation receiverAlignment passResult  playAction  \
# 13368         10          SHOTGUN               2x2          C       False
#
#        timeToThrow pff_passCoverage pff_manZone
# 13368        2.169     Cover 6-Left        Zone

# %%
filteredplays
# Out:
#            gameId  playId possessionTeam defensiveTeam  quarter  down  \
# 0      2022102302    2655            CIN           ATL        3     1
# 1      2022091809    3698            CIN           DAL        4     1
# 2      2022103004    3146            HOU           TEN        4     3
# 3      2022110610     348             KC           TEN        1     2
# 8      2022091104    3662            PHI           DET        4     3
# ...           ...     ...            ...           ...      ...   ...
# 16117  2022100901    2213            PIT           BUF        3     1
# 16119  2022110604    1051            JAX            LV        2     3
# 16120  2022103005    3492            MIN           ARI        4     1
# 16121  2022092502    2337             KC           IND        3     1
# 16122  2022091809     719            DAL           CIN        1     1
#
#        yardsToGo offenseFormation receiverAlignment passResult  playAction  \
# 0             10            EMPTY               3x2          C       False
# 1             10            EMPTY               3x2          C       False
# 2             12          SHOTGUN               2x2          C       False
# 3             10          SHOTGUN               2x2          C       False
# 8             12          SHOTGUN               3x1          I       False
# ...          ...              ...               ...        ...         ...
# 16117         10           I_FORM               2x1          C        True
# 16119          4          SHOTGUN               2x2          I       False
# 16120         10          SHOTGUN               2x2          I       False
# 16121         10          SHOTGUN               2x2          R       False
# 16122         10       SINGLEBACK               2x2          I        True
#
#        timeToThrow pff_passCoverage pff_manZone
# 0            2.990          Cover-3        Zone
# 1            1.836         Quarters        Zone
# 2            2.236         Quarters        Zone
# 3            2.202         Quarters        Zone
# 8            1.568          Cover-0         Man
# ...            ...              ...         ...
# 16117        3.838         Quarters        Zone
# 16119        1.860          Cover-2        Zone
# 16120        3.136          Cover-3        Zone
# 16121          NaN         Quarters        Zone
# 16122        3.070          Cover-3        Zone
#
# [9736 rows x 14 columns]

# %%
cols2 = ['gameId', 'playId', 'nflId','teamAbbr','inMotionAtBallSnap', 'motionSinceLineset', 'routeRan', 'hadPassReception', 'receivingYards']

# %%
filteredplayerplay = playerplay[cols2][playerplay['routeRan'].notna()]

# %%
filteredplayerplay
# Out:
#             gameId  playId  nflId teamAbbr inMotionAtBallSnap  \
# 2       2022090800      56  42489      BUF              False
# 4       2022090800      56  44985      BUF              False
# 7       2022090800      56  47879      BUF              False
# 9       2022090800      56  52536      BUF              False
# 68      2022090800     122  42489      BUF              False
# ...            ...     ...    ...      ...                ...
# 354522  2022110700    3480  44879       NO              False
# 354523  2022110700    3480  46160       NO              False
# 354526  2022110700    3480  52942       NO              False
# 354527  2022110700    3480  53098       NO              False
# 354528  2022110700    3480  54476       NO              False
#
#        motionSinceLineset routeRan  hadPassReception  receivingYards
# 2                    True       IN                 1               6
# 4                   False      OUT                 0               0
# 7                   False       IN                 0               0
# 9                   False       GO                 0               0
# 68                  False       GO                 0               0
# ...                   ...      ...               ...             ...
# 354522              False     FLAT                 0               0
# 354523              False       IN                 0               0
# 354526              False      OUT                 1              41
# 354527              False       IN                 0               0
# 354528              False       GO                 0               0
#
# [42779 rows x 9 columns]

# %%
merged_playerplay = pd.merge(
    filteredplays[['gameId','playId','possessionTeam','defensiveTeam','quarter','down','yardsToGo','offenseFormation','receiverAlignment','passResult','playAction','timeToThrow','pff_passCoverage','pff_manZone']],
    filteredplayerplay[['gameId','playId','nflId','inMotionAtBallSnap','motionSinceLineset','routeRan','hadPassReception','receivingYards']],
    how='right',
    left_on=['gameId', 'playId'],
    right_on=['gameId', 'playId']
)

# %%
merged_playerplay
# Out:
#            gameId  playId possessionTeam defensiveTeam  quarter  down  \
# 0      2022090800      56            BUF            LA        1     1
# 1      2022090800      56            BUF            LA        1     1
# 2      2022090800      56            BUF            LA        1     1
# 3      2022090800      56            BUF            LA        1     1
# 4      2022090800     122            BUF            LA        1     2
# ...           ...     ...            ...           ...      ...   ...
# 42774  2022110700    3480             NO           BAL        4     2
# 42775  2022110700    3480             NO           BAL        4     2
# 42776  2022110700    3480             NO           BAL        4     2
# 42777  2022110700    3480             NO           BAL        4     2
# 42778  2022110700    3480             NO           BAL        4     2
#
#        yardsToGo offenseFormation receiverAlignment passResult  playAction  \
# 0             10          SHOTGUN               2x2          C       False
# 1             10          SHOTGUN               2x2          C       False
# 2             10          SHOTGUN               2x2          C       False
# 3             10          SHOTGUN               2x2          C       False
# 4              3          SHOTGUN               2x1          C       False
# ...          ...              ...               ...        ...         ...
# 42774         10          SHOTGUN               2x2          C       False
# 42775         10          SHOTGUN               2x2          C       False
# 42776         10          SHOTGUN               2x2          C       False
# 42777         10          SHOTGUN               2x2          C       False
# 42778         10          SHOTGUN               2x2          C       False
#
#        timeToThrow pff_passCoverage pff_manZone  nflId inMotionAtBallSnap  \
# 0            2.169     Cover 6-Left        Zone  42489              False
# 1            2.169     Cover 6-Left        Zone  44985              False
# 2            2.169     Cover 6-Left        Zone  47879              False
# 3            2.169     Cover 6-Left        Zone  52536              False
# 4            2.903          Cover-3        Zone  42489              False
# ...            ...              ...         ...    ...                ...
# 42774        2.390          Cover-3        Zone  44879              False
# 42775        2.390          Cover-3        Zone  46160              False
# 42776        2.390          Cover-3        Zone  52942              False
# 42777        2.390          Cover-3        Zone  53098              False
# 42778        2.390          Cover-3        Zone  54476              False
#
#       motionSinceLineset routeRan  hadPassReception  receivingYards
# 0                   True       IN                 1               6
# 1                  False      OUT                 0               0
# 2                  False       IN                 0               0
# 3                  False       GO                 0               0
# 4                  False       GO                 0               0
# ...                  ...      ...               ...             ...
# 42774              False     FLAT                 0               0
# 42775              False       IN                 0               0
# 42776              False      OUT                 1              41
# 42777              False       IN                 0               0
# 42778              False       GO                 0               0
#
# [42779 rows x 20 columns]

# %%
tracking_data = pd.read_csv('tracking_week_1.csv')

# %%
tracking = tracking_data[tracking_data['frameType'] == 'AFTER_SNAP']

# %%
route_runners = playerplay[playerplay['routeRan'].notna()][['gameId', 'playId', 'nflId', 'routeRan']]
defenders = playerplay[playerplay['pff_primaryDefensiveCoverageMatchupNflId'].notna()][['gameId', 'playId', 'nflId', 'pff_primaryDefensiveCoverageMatchupNflId']]
defenders = defenders.rename(columns={'pff_primaryDefensiveCoverageMatchupNflId': 'routeRunnerId'})

# %%
merged_df = defenders.merge(route_runners, left_on=['gameId', 'playId', 'routeRunnerId'], right_on=['gameId', 'playId', 'nflId'])

# %%
defenders = merged_df[['gameId','playId','nflId_x','routeRunnerId']]

# %%
route = pd.merge(
    tracking[['gameId', 'playId', 'nflId', 'frameId', 'time', 'x', 'y']],  # Columns to keep from tracking_df
    route_runners[['gameId', 'playId', 'nflId']],  # Only keep necessary columns from route_runners_df
    on=['gameId', 'playId', 'nflId'],  # Merge on these columns
    how='inner'  # Use an inner join to keep only matching nflIds
)

# %%
defend = pd.merge(
    tracking[['gameId', 'playId', 'nflId', 'frameId','time', 'x', 'y']],  # Columns to keep from tracking_df
    defenders[['gameId', 'playId', 'nflId_x', 'routeRunnerId']],  # Necessary columns from defenders_df
    left_on=['gameId', 'playId', 'nflId'],  # Merge on these columns
    right_on=['gameId', 'playId', 'nflId_x'],  # Use nflId_x for the defenders DataFrame
    how='inner'  # Use an inner join to keep only matching nflIds
)

# %%
merged_df = pd.merge(
    route,  # Use the entire route_df
    defend[['gameId','playId','nflId','frameId','x','y','routeRunnerId']],  # Use the entire defend_df
    how='inner',  # Use an inner join to keep only matching rows
    left_on=['gameId', 'playId', 'nflId', 'frameId'],  # Merge on these columns in route_df
    right_on=['gameId', 'playId', 'routeRunnerId', 'frameId']  # Match nflId in route_df with routeRunnerId in defend_df
)

# %%
merged_df['time_since_snap'] = 0.1

# %%
def calculate_time_since_snap(df):
    time = 0.1  # Default time
    lasttime = 0.1
    
    # Initialize last identifiers
    lastgame = None
    lastplay = None
    lastplayer = None
    lastframe = None
    
    # Iterate through each row in the DataFrame
    for i in range(len(df)):
        current_row = df.iloc[i]
        
        # Check if we're still in the same game, play, and player
        if (current_row['gameId'] == lastgame and
                current_row['playId'] == lastplay and
                current_row['nflId_x'] == lastplayer):
            if current_row['frameId'] == lastframe:
                df.at[i, 'time_since_snap'] = lasttime
            elif current_row['frameId'] == lastframe + 1:
                lasttime += 0.1
                df.at[i, 'time_since_snap'] = lasttime
            else:
                # Reset time since snap if frameId is not consecutive
                lasttime = 0.1
                df.at[i, 'time_since_snap'] = lasttime
        else:
            # If gameId, playId, or nflId_x changes, reset
            df.at[i, 'time_since_snap'] = time
            lasttime = time  # Reset lasttime to default

        # Update last identifiers
        lastgame = current_row['gameId']
        lastplay = current_row['playId']
        lastplayer = current_row['nflId_x']
        lastframe = current_row['frameId']

    return df

# %%
merged_df = calculate_time_since_snap(merged_df)

# %%
merged_df
# Out:
#             gameId  playId  nflId_x  frameId                   time    x_x  \
# 0       2022091200      85  40026.0      118  2022-09-13 00:16:52.2  39.24
# 1       2022091200      85  40026.0      118  2022-09-13 00:16:52.2  39.24
# 2       2022091200      85  40026.0      119  2022-09-13 00:16:52.3  39.32
# 3       2022091200      85  40026.0      119  2022-09-13 00:16:52.3  39.32
# 4       2022091200      85  40026.0      120  2022-09-13 00:16:52.4  39.45
# ...            ...     ...      ...      ...                    ...    ...
# 278883  2022090800    3696  53678.0      171  2022-09-09 03:07:37.7   3.01
# 278884  2022090800    3696  53678.0      172  2022-09-09 03:07:37.8   2.71
# 278885  2022090800    3696  53678.0      173  2022-09-09 03:07:37.9   2.43
# 278886  2022090800    3696  53678.0      174    2022-09-09 03:07:38   2.17
# 278887  2022090800    3696  53678.0      175  2022-09-09 03:07:38.1   1.95
#
#           y_x  nflId_y    x_y    y_y  routeRunnerId  time_since_snap
# 0       34.29  35459.0  54.43  34.34        40026.0              0.1
# 1       34.29  42929.0  44.44  30.18        40026.0              0.1
# 2       34.27  35459.0  54.52  34.35        40026.0              0.2
# 3       34.27  42929.0  44.45  30.22        40026.0              0.2
# 4       34.25  35459.0  54.62  34.35        40026.0              0.3
# ...       ...      ...    ...    ...            ...              ...
# 278883  50.29  54488.0   7.11  49.36        53678.0              4.9
# 278884  50.21  54488.0   7.03  49.24        53678.0              5.0
# 278885  50.12  54488.0   6.96  49.12        53678.0              5.1
# 278886  50.02  54488.0   6.89  49.00        53678.0              5.2
# 278887  49.91  54488.0   6.83  48.88        53678.0              5.3
#
# [278888 rows x 12 columns]

# %%
merge = pd.merge(
    merged_df,
    plays[['gameId', 'playId', 'timeToThrow']],
    how='left',
    left_on=['gameId', 'playId'],  
    right_on=['gameId', 'playId']  
)

# %%
merge = merge[(merge['time_since_snap'] <= merge['timeToThrow']) & (merge['time_since_snap'] >= 1)]

# %%
final = merge[['gameId', 'playId', 'frameId', 'nflId_x', 'nflId_y', 'x_x', 'y_x', 'x_y', 'y_y', 'time_since_snap', 'timeToThrow']]

# %%
final.rename(columns={
    'nflId_x': 'nflId_runner',
    'nflId_y': 'nflId_defender',
    'x_x': 'x_runner', 
    'y_x': 'y_runner', 
    'x_y': 'x_defender',
    'y_y': 'y_defender'
}, inplace=True)
# Out:
# C:\Users\bhaga\AppData\Local\Temp\ipykernel_40644\911467374.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final.rename(columns={

# %%
final['separation'] = ((final['x_runner'] - final['x_defender'])**2 + (final['y_runner'] - final['y_defender'])**2)**0.5
# Out:
# C:\Users\bhaga\AppData\Local\Temp\ipykernel_40644\3475080978.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['separation'] = ((final['x_runner'] - final['x_defender'])**2 + (final['y_runner'] - final['y_defender'])**2)**0.5

# %%
final
# Out:
#             gameId  playId  frameId  nflId_runner  nflId_defender  x_runner  \
# 20      2022091200      85      128       40026.0         35459.0     42.41
# 21      2022091200      85      128       40026.0         42929.0     42.41
# 22      2022091200      85      129       40026.0         35459.0     43.00
# 23      2022091200      85      129       40026.0         42929.0     43.00
# 24      2022091200      85      130       40026.0         35459.0     43.62
# ...            ...     ...      ...           ...             ...       ...
# 278855  2022090800    3696      143       53678.0         54488.0     20.23
# 278856  2022090800    3696      144       53678.0         54488.0     19.56
# 278857  2022090800    3696      145       53678.0         54488.0     18.88
# 278858  2022090800    3696      146       53678.0         54488.0     18.19
# 278859  2022090800    3696      147       53678.0         54488.0     17.51
#
#         y_runner  x_defender  y_defender  time_since_snap  timeToThrow  \
# 20         33.71       56.00       34.50              1.1        2.069
# 21         33.71       45.11       31.30              1.1        2.069
# 22         33.65       56.28       34.55              1.2        2.069
# 23         33.65       45.23       31.47              1.2        2.069
# 24         33.60       56.57       34.61              1.3        2.069
# ...          ...         ...         ...              ...          ...
# 278855     46.00       16.82       46.89              2.1        2.569
# 278856     46.32       16.40       47.09              2.2        2.569
# 278857     46.63       15.98       47.28              2.3        2.569
# 278858     46.95       15.54       47.49              2.4        2.569
# 278859     47.29       15.10       47.69              2.5        2.569
#
#         separation
# 20       13.612942
# 21        3.619130
# 22       13.310462
# 23        3.118541
# 24       12.989326
# ...            ...
# 278855    3.524230
# 278856    3.252461
# 278857    2.971952
# 278858    2.704459
# 278859    2.442970
#
# [82317 rows x 12 columns]

# %%
final = final.loc[final.groupby(['gameId', 'playId', 'frameId', 'nflId_runner'])['separation'].idxmin()]

# %%
final
# Out:
#             gameId  playId  frameId  nflId_runner  nflId_defender  x_runner  \
# 262240  2022090800      56      157       42489.0         43294.0     83.83
# 262286  2022090800      56      157       44985.0         47844.0     84.67
# 262343  2022090800      56      157       47879.0         53532.0     84.03
# 262241  2022090800      56      158       42489.0         43294.0     83.40
# 262287  2022090800      56      158       44985.0         47844.0     84.20
# ...            ...     ...      ...           ...             ...       ...
# 18261   2022091200    3826      117       52454.0         47941.0     53.77
# 18346   2022091200    3826      117       53464.0         42827.0     70.68
# 18177   2022091200    3826      118       46109.0         54618.0     55.99
# 18262   2022091200    3826      118       52454.0         47941.0     52.95
# 18347   2022091200    3826      118       53464.0         42827.0     70.68
#
#         y_runner  x_defender  y_defender  time_since_snap  timeToThrow  \
# 262240     43.53       77.45       43.82              1.1        2.169
# 262286     18.65       82.10       22.20              1.1        2.169
# 262343     34.53       79.61       32.75              1.1        2.169
# 262241     43.45       77.42       43.83              1.2        2.169
# 262287     18.77       81.85       22.10              1.2        2.169
# ...          ...         ...         ...              ...          ...
# 18261      41.65       52.99       44.36              2.7        2.836
# 18346      16.58       57.86       18.40              2.7        2.836
# 18177      15.63       56.20       15.01              2.8        2.836
# 18262      41.84       52.68       44.43              2.8        2.836
# 18347      16.09       57.89       17.81              2.8        2.836
#
#         separation
# 262240    6.386588
# 262286    4.382625
# 262343    4.764955
# 262241    5.992061
# 262287    4.075709
# ...            ...
# 18261     2.820018
# 18346    12.948544
# 18177     0.654599
# 18262     2.604035
# 18347    12.905135
#
# [74309 rows x 12 columns]

# %%
max_separation_per_play = final.groupby(['gameId', 'playId', 'nflId_runner'])['separation'].max().reset_index()
max_separation_per_play.columns = ['gameId', 'playId', 'routeRunnerId', 'maxSeparation']

# %%
result = pd.merge(
    max_separation_per_play,
    final[['gameId', 'playId', 'nflId_runner', 'nflId_defender', 'separation', 'time_since_snap', 'timeToThrow']],  # Select necessary columns
    how='left',
    left_on=['gameId', 'playId', 'routeRunnerId', 'maxSeparation'],  # Join on the maximum separation
    right_on=['gameId', 'playId', 'nflId_runner', 'separation']  # Join on the separation value
)

# %%
result = result.drop(columns=['nflId_runner'])
result
# Out:
#           gameId  playId  routeRunnerId  maxSeparation  nflId_defender  \
# 0     2022090800      56        42489.0       6.386588         43294.0
# 1     2022090800      56        44985.0       4.382625         47844.0
# 2     2022090800      56        47879.0       4.764955         53532.0
# 3     2022090800     122        42489.0       7.504166         42816.0
# 4     2022090800     122        44985.0       5.287343         43294.0
# ...          ...     ...            ...            ...             ...
# 4151  2022091200    3795        52454.0       7.688654         47941.0
# 4152  2022091200    3795        52526.0       5.955476         44873.0
# 4153  2022091200    3826        46109.0       1.381774         54618.0
# 4154  2022091200    3826        52454.0       8.478095         47941.0
# 4155  2022091200    3826        53464.0      12.948544         42827.0
#
#       separation  time_since_snap  timeToThrow
# 0       6.386588              1.1        2.169
# 1       4.382625              1.1        2.169
# 2       4.764955              1.1        2.169
# 3       7.504166              1.1        2.903
# 4       5.287343              1.1        2.903
# ...          ...              ...          ...
# 4151    7.688654              1.1        1.983
# 4152    5.955476              1.1        1.983
# 4153    1.381774              1.1        2.836
# 4154    8.478095              1.1        2.836
# 4155   12.948544              2.7        2.836
#
# [4156 rows x 8 columns]

# %%
merged_playerplay.columns
# Out:
# Index(['gameId', 'playId', 'possessionTeam', 'defensiveTeam', 'quarter',
#        'down', 'yardsToGo', 'offenseFormation', 'receiverAlignment',
#        'passResult', 'playAction', 'timeToThrow', 'pff_passCoverage',
#        'pff_manZone', 'nflId', 'inMotionAtBallSnap', 'motionSinceLineset',
#        'routeRan', 'hadPassReception', 'receivingYards'],
#       dtype='object')

# %%
week1 = pd.merge(
    merged_playerplay,
    result,
    how = 'right',
    left_on=['gameId','playId','nflId'],
    right_on=['gameId','playId','routeRunnerId']
)

# %%
week1.columns
# Out:
# Index(['gameId', 'playId', 'possessionTeam', 'defensiveTeam', 'quarter',
#        'down', 'yardsToGo', 'offenseFormation', 'receiverAlignment',
#        'passResult', 'playAction', 'timeToThrow_x', 'pff_passCoverage',
#        'pff_manZone', 'nflId', 'inMotionAtBallSnap', 'motionSinceLineset',
#        'routeRan', 'hadPassReception', 'receivingYards', 'routeRunnerId',
#        'maxSeparation', 'nflId_defender', 'separation', 'time_since_snap',
#        'timeToThrow_y'],
#       dtype='object')

# %%
new_column_order = [
    'gameId', 
    'playId', 
    'routeRunnerId',  # Move routeRunnerId to 3rd
    'nflId_defender',  # Move nflId_defender to 4th
    'possessionTeam', 
    'defensiveTeam', 
    'quarter', 
    'down', 
    'yardsToGo', 
    'offenseFormation', 
    'receiverAlignment', 
    'passResult', 
    'playAction', 
    'timeToThrow_x', 
    'pff_passCoverage', 
    'pff_manZone', 
    'inMotionAtBallSnap', 
    'motionSinceLineset', 
    'routeRan', 
    'hadPassReception', 
    'receivingYards',
    'time_since_snap',
    'maxSeparation'
]

# %%
week1 = week1.drop(columns='nflId')

# %%
week1 = week1[new_column_order]
week1.columns
# Out:
# Index(['gameId', 'playId', 'routeRunnerId', 'nflId_defender', 'possessionTeam',
#        'defensiveTeam', 'quarter', 'down', 'yardsToGo', 'offenseFormation',
#        'receiverAlignment', 'passResult', 'playAction', 'timeToThrow_x',
#        'pff_passCoverage', 'pff_manZone', 'inMotionAtBallSnap',
#        'motionSinceLineset', 'routeRan', 'hadPassReception', 'receivingYards',
#        'time_since_snap', 'maxSeparation'],
#       dtype='object')

# %%
week1
# Out:
#           gameId  playId  routeRunnerId  nflId_defender possessionTeam  \
# 0     2022090800      56        42489.0         43294.0            BUF
# 1     2022090800      56        44985.0         47844.0            BUF
# 2     2022090800      56        47879.0         53532.0            BUF
# 3     2022090800     122        42489.0         42816.0            BUF
# 4     2022090800     122        44985.0         43294.0            BUF
# ...          ...     ...            ...             ...            ...
# 4151  2022091200    3795        52454.0         47941.0            DEN
# 4152  2022091200    3795        52526.0         44873.0            DEN
# 4153  2022091200    3826        46109.0         54618.0            DEN
# 4154  2022091200    3826        52454.0         47941.0            DEN
# 4155  2022091200    3826        53464.0         42827.0            DEN
#
#      defensiveTeam  quarter  down  yardsToGo offenseFormation  ...  \
# 0               LA        1     1         10          SHOTGUN  ...
# 1               LA        1     1         10          SHOTGUN  ...
# 2               LA        1     1         10          SHOTGUN  ...
# 3               LA        1     2          3          SHOTGUN  ...
# 4               LA        1     2          3          SHOTGUN  ...
# ...            ...      ...   ...        ...              ...  ...
# 4151           SEA        4     2         14          SHOTGUN  ...
# 4152           SEA        4     2         14          SHOTGUN  ...
# 4153           SEA        4     3         14          SHOTGUN  ...
# 4154           SEA        4     3         14          SHOTGUN  ...
# 4155           SEA        4     3         14          SHOTGUN  ...
#
#      timeToThrow_x pff_passCoverage  pff_manZone  inMotionAtBallSnap  \
# 0            2.169     Cover 6-Left         Zone               False
# 1            2.169     Cover 6-Left         Zone               False
# 2            2.169     Cover 6-Left         Zone               False
# 3            2.903          Cover-3         Zone               False
# 4            2.903          Cover-3         Zone               False
# ...            ...              ...          ...                 ...
# 4151         1.983          Cover-3         Zone               False
# 4152         1.983          Cover-3         Zone               False
# 4153         2.836     Cover 6-Left         Zone               False
# 4154         2.836     Cover 6-Left         Zone               False
# 4155         2.836     Cover 6-Left         Zone               False
#
#      motionSinceLineset routeRan hadPassReception receivingYards  \
# 0                  True       IN                1              6
# 1                 False      OUT                0              0
# 2                 False       IN                0              0
# 3                 False       GO                0              0
# 4                 False     POST                0              0
# ...                 ...      ...              ...            ...
# 4151              False    HITCH                0              0
# 4152              False    SLANT                0              0
# 4153              False       GO                0              0
# 4154              False       GO                0              0
# 4155              False     FLAT                1              9
#
#      time_since_snap  maxSeparation
# 0                1.1       6.386588
# 1                1.1       4.382625
# 2                1.1       4.764955
# 3                1.1       7.504166
# 4                1.1       5.287343
# ...              ...            ...
# 4151             1.1       7.688654
# 4152             1.1       5.955476
# 4153             1.1       1.381774
# 4154             1.1       8.478095
# 4155             2.7      12.948544
#
# [4156 rows x 23 columns]

# %%
week1.loc[week1['maxSeparation'] > 20, ['time_since_snap', 'timeToThrow_x', 'pff_manZone','hadPassReception', 'receivingYards', 'maxSeparation']]
# Out:
#       time_since_snap  timeToThrow_x pff_manZone  hadPassReception  \
# 355               1.1          3.403        Zone                 0
# 717               7.9          7.920        Zone                 1
# 728               5.3          5.338         Man                 0
# 771               1.1          2.770        Zone                 0
# 857               5.1          5.165        Zone                 0
# 925               1.1          2.836        Zone                 0
# 1256              2.6          2.679        Zone                 0
# 1260              2.2          2.269        Zone                 0
# 1337              3.4          3.431        Zone                 0
# 1518              1.1          3.031        Zone                 0
# 1558              3.5          3.550        Zone                 1
# 1822              2.0          3.471        Zone                 0
# 1936              1.1          2.837        Zone                 0
# 1940              1.1          2.969        Zone                 1
# 2103              1.1          2.837        Zone                 0
# 2584              3.1          3.170        Zone                 1
# 2587              3.1          3.170        Zone                 0
# 2835              3.8          3.971        Zone                 1
# 2951              5.0          5.005        Zone                 0
# 3513              1.1          3.803        Zone                 1
# 3607              1.1          5.339        Zone                 0
# 3642              1.1          1.969        Zone                 1
# 3672              3.8          4.498        Zone                 0
# 3715              3.0          3.904        Zone                 0
# 3931              3.8          6.774        Zone                 0
# 3933              1.1          3.126        Zone                 0
# 3991              3.5          3.571        Zone                 0
#
#       receivingYards  maxSeparation
# 355                0      22.696795
# 717               51      24.001594
# 728                0      28.998464
# 771                0      22.403397
# 857                0      22.530142
# 925                0      21.107139
# 1256               0      21.061208
# 1260               0      24.907690
# 1337               0      23.536179
# 1518               0      22.569293
# 1558               4      20.718844
# 1822               0      20.380886
# 1936               0      20.384968
# 1940               5      21.705163
# 2103               0      20.059177
# 2584               4      34.771603
# 2587               0      40.524151
# 2835              25      21.245856
# 2951               0      25.876911
# 3513              36      23.289161
# 3607               0      23.011358
# 3642              13      23.392772
# 3672               0      22.684276
# 3715               0      21.939674
# 3931               0      23.891609
# 3933               0      20.193794
# 3991               0      30.633454

# %%
week1[week1['hadPassReception']==1]
# Out:
#           gameId  playId  routeRunnerId  nflId_defender possessionTeam  \
# 0     2022090800      56        42489.0         43294.0            BUF
# 5     2022090800     122        47857.0         38577.0            BUF
# 7     2022090800     167        42489.0         43298.0            BUF
# 13    2022090800     212        52494.0         38577.0            BUF
# 15    2022090800     236        52536.0         43294.0            BUF
# ...          ...     ...            ...             ...            ...
# 4130  2022091200    3491        47803.0         53534.0            SEA
# 4139  2022091200    3596        52526.0         42543.0            DEN
# 4144  2022091200    3628        52526.0         44873.0            DEN
# 4148  2022091200    3723        53464.0         52435.0            DEN
# 4155  2022091200    3826        53464.0         42827.0            DEN
#
#      defensiveTeam  quarter  down  yardsToGo offenseFormation  ...  \
# 0               LA        1     1         10          SHOTGUN  ...
# 5               LA        1     2          3          SHOTGUN  ...
# 7               LA        1     2          8            EMPTY  ...
# 13              LA        1     2          9          SHOTGUN  ...
# 15              LA        1     3          1           I_FORM  ...
# ...            ...      ...   ...        ...              ...  ...
# 4130           DEN        4     2          8          SHOTGUN  ...
# 4139           SEA        4     3          5          SHOTGUN  ...
# 4144           SEA        4     1         10          SHOTGUN  ...
# 4148           SEA        4     3          2          SHOTGUN  ...
# 4155           SEA        4     3         14          SHOTGUN  ...
#
#      timeToThrow_x pff_passCoverage  pff_manZone  inMotionAtBallSnap  \
# 0            2.169     Cover 6-Left         Zone               False
# 5            2.903          Cover-3         Zone               False
# 7            1.868          Cover-3         Zone               False
# 13           4.905          Cover-1          Man               False
# 15           2.636          Cover-3         Zone                True
# ...            ...              ...          ...                 ...
# 4130         2.478         Quarters         Zone               False
# 4139         3.029          Cover-3         Zone               False
# 4144         1.902     Cover-3 Seam         Zone               False
# 4148         2.717     Cover-3 Seam         Zone               False
# 4155         2.836     Cover 6-Left         Zone               False
#
#      motionSinceLineset routeRan hadPassReception receivingYards  \
# 0                  True       IN                1              6
# 5                 False     FLAT                1              6
# 7                 False    SLANT                1             12
# 13                False    ANGLE                1              8
# 15                 True   CORNER                1             26
# ...                 ...      ...              ...            ...
# 4130              False   SCREEN                1              2
# 4139              False    HITCH                1              5
# 4144              False    HITCH                1              6
# 4148              False      OUT                1              9
# 4155              False     FLAT                1              9
#
#      time_since_snap  maxSeparation
# 0                1.1       6.386588
# 5                2.3      11.756330
# 7                1.1       2.651886
# 13               1.1       8.402869
# 15               2.6       7.888346
# ...              ...            ...
# 4130             2.4       3.800118
# 4139             1.1      10.800463
# 4144             1.1       9.984813
# 4148             1.9       7.553125
# 4155             2.7      12.948544
#
# [606 rows x 23 columns]
